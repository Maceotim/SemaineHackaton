# %%
import df
import sys
sys.path.append('C:/Users/bonna/Desktop/hackathon/SemaineHackaton/df.py')
print(df.df.head())
# Out:
#       essai  P6_reel    E1    V  ...    P3         P4  P5  P6_target
# 0  392291.0      3.2  86.5  0.0  ...  16.0  14.712644  48        3.0
# 1  392291.0      3.2  84.5  0.0  ...  16.0  14.712644  48        3.0
# 2  392291.0      3.2  87.9  0.0  ...  16.0  14.712644  48        3.0
# 3  392291.0      3.2  84.6  0.0  ...  16.0  14.712644  48        3.0
# 4  392291.0      3.2  88.4  0.0  ...  16.0  14.712644  48        3.0
#
# [5 rows x 34 columns]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df.head()
#
# AttributeError: module 'df' has no attribute 'head'

# %%
from sklearn import model_selection
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from sklearn import model_selection
#
# ModuleNotFoundError: No module named 'sklearn'
